# %% [markdown]
# ## 2.6 Q러닝 구현

# %%
# 구현에 사용할 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 정책 파라미터 theta_0을 무작위 행동 정책 pi로 변환하는 함수


def simple_convert_into_pi_from_theta(theta):
    '''단순 비율 계산'''

    [m, n] = theta.shape  # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 비율 계산

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# 무작위 행동정책 pi_0을 계산
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 행동가치 함수 Q의 초기 상태

[a, b] = theta_0.shape  # # 열과 행의 갯수를 변수 a, b에 저장
Q = np.random.rand(a, b) * theta_0 * 0.1
# * theta0 로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# ε-greedy 알고리즘 구현


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 행동을 결정
    if np.random.rand() < epsilon:
        # 확률 ε로 무작위 행동을 선택함
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Q값이 최대가 되는 행동을 선택함
        next_direction = direction[np.nanargmax(Q[s, :])]

    # 행동을 인덱스로 변환
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 행동 a의 방향
    
    # 행동으로 다음 상태를 결정
    if next_direction == "up":
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return s_next

# %%
# Q러닝 알고리즘으로 행동가치 함수 Q를 수정


def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 8:  # 목표 지점에 도달한 경우
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])

    return Q

# %%
# Q러닝 알고리즘으로 미로를 빠져나오는 함수, 상태 및 행동 그리고 Q값의 히스토리를 출력한다


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # 시작 지점
    a = a_next = get_action(s, Q, epsilon, pi)  # 첫 번째 행동
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        a = a_next  # 행동 결정

        s_a_history[-1][1] = a
        # 현재 상태(마지막으로 인덱스가 -1)을 히스토리에 추가

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 다음 단계의 상태를 구함

        s_a_history.append([s_next, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다

        # 보상을 부여하고 다음 행동을 계산함
        if s_next == 8:
            r = 1  # 목표 지점에 도달했다면 보상을 부여
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 다음 행동 a_next를 계산

        # 가치함수를 수정
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 종료 여부 판정
        if s_next == 8:  # 목표 지점에 도달하면 종료
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Q러닝 알고리즘으로 미로 빠져나오기

eta = 0.1  # 학습률
gamma = 0.9  # 시간할인율
epsilon = 0.5  # ε-greedy 알고리즘 epsilon 초깃값
v = np.nanmax(Q, axis=1)  # 각 상태마다 가치의 최댓값을 계산
is_continue = True
episode = 1

V = []  # 에피소드 별로 상태가치를 저장
V.append(np.nanmax(Q, axis=1))  # 상태 별로 행동가치의 최댓값을 계산

while is_continue:  # is_continue의 값이 False가 될 때까지 반복
    print("에피소드: " + str(episode))

    # ε 값을 조금씩 감소시킴
    epsilon = epsilon / 2

    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    # Q러닝으로 미로를 빠져나온 후, 결과로 나온 행동 히스토리와 Q값을 변수에 저장
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 상태가치의 변화
    new_v = np.nanmax(Q, axis=1)  # 각 상태마다 행동가치의 최댓값을 계산
    print(np.sum(np.abs(new_v - v)))  # 상태가치 함수의 변화를 출력
    v = new_v
    V.append(v)  # 현재 에피소드가 끝난 시점의 상태가치 함수를 추가

    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다")

    # 100 에피소드 반복
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 에피소드: 1
# 0.13627298440392863
# 목표 지점에 이르기까지 걸린 단계 수는 26단계입니다
# 에피소드: 2
# 0.18298641921768805
# 목표 지점에 이르기까지 걸린 단계 수는 144단계입니다
# 에피소드: 3
# 0.11116413551003146
# 목표 지점에 이르기까지 걸린 단계 수는 58단계입니다
# 에피소드: 4
# 0.09944387685853881
# 목표 지점에 이르기까지 걸린 단계 수는 62단계입니다
# 에피소드: 5
# 0.0919809972368715
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 6
# 0.09067761724842308
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 7
# 0.08903694946720797
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 8
# 0.08814426520742341
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 9
# 0.08720789297847006
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 10
# 0.0862149762438788
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 11
# 0.08515508940201036
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 12
# 0.08402030082461501
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 13
# 0.0828051206188195
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 14
# 0.081506367002775
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 15
# 0.08012297805044535
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 16
# 0.07865578970156466
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 17
# 0.07710729614255289
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 18
# 0.07548140476816367
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 19
# 0.0737831947834481
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 20
# 0.07201868597562516
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 21
# 0.07019462216952883
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 22
# 0.0683182722889085
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 23
# 0.06639725070366273
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 24
# 0.0644393575868289
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 25
# 0.06245243928181293
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 26
# 0.060444268145665614
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 27
# 0.05842244095130486
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 28
# 0.056394294669811135
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 29
# 0.05436683828794181
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 30
# 0.052346699224942284
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 31
# 0.05034008287941283
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 32
# 0.048352743847442314
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 33
# 0.04638996739605877
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 34
# 0.04445655984212543
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 35
# 0.04255684656876457
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 36
# 0.0406946765034234
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 37
# 0.0388734319792125
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 38
# 0.03709604300062558
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 39
# 0.03536500503349599
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 40
# 0.03368239953503266
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 41
# 0.03204991653158995
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 42
# 0.030468878638428953
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 43
# 0.028940265996495573
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 44
# 0.027464741675800763
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 45
# 0.026042677163196748
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 46
# 0.024674177614224968
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 47
# 0.0233591066044071
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 48
# 0.022097110165121947
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 49
# 0.02088763993332654
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 50
# 0.019729975283241163
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 51
# 0.01862324434204532
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 52
# 0.017566443821054878
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 53
# 0.01655845761913266
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 54
# 0.015598074176620846
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 55
# 0.014684002576230037
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 56
# 0.013814887402448184
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 57
# 0.01298932238344852
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 58
# 0.012205862849521965
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 59
# 0.011463037049994296
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 60
# 0.01075935637669212
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 61
# 0.010093324546544657
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 62
# 0.009463445799049452
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 63
# 0.008868232166303502
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 64
# 0.008306209874289205
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 65
# 0.007775924934245837
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 66
# 0.007275947982424924
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 67
# 0.006804878425409666
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 68
# 0.006361347946630347
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 69
# 0.0059440234277695625
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 70
# 0.005551609336573615
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 71
# 0.005182849630167019
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 72
# 0.004836529220445418
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 73
# 0.004511475045481328
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 74
# 0.004206556788208582
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 75
# 0.0039206872809784965
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 76
# 0.003652822631917352
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 77
# 0.0034019621064235173
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 78
# 0.003167147794596148
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 79
# 0.0029474640929481044
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 80
# 0.0027420370264067406
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 81
# 0.0025500334343536712
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 82
# 0.00237066004233899
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 83
# 0.002203162439080253
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 84
# 0.002046823976471268
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 85
# 0.0019009646085476062
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 86
# 0.001764939683700173
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 87
# 0.0016381387028890915
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 88
# 0.001519984055180279
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 89
# 0.0014099297406090505
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 90
# 0.0013074600891657129
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 91
# 0.0012120884835763457
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 92
# 0.001123356092542438
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 93
# 0.001040830620164468
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 94
# 0.0009641050764434
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 95
# 0.00089279657297614
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 96
# 0.0008265451472813101
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 97
# 0.0007650126185684281
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 98
# 0.0007078814772024655
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 99
# 0.0006548538096292633
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다
# 에피소드: 100
# 0.0006056502600754188
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다

# %%
# 상태가치의 변화를 시각화
# 참고 URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 배경색 초기화
    line.set_data([], [])
    return (line,)


def animate(i):
    # 프레임 단위로 그림을 그림
    # 각 칸에 상태가치 값으로 결정된 색을 칠함
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)


# 초기화 함수와 프레임 단위로 그림을 그리는 함수로 애니메이션을 생성
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9298cc8c32304744b74f8c3090afce01">
#   <div class="anim-controls">
#     <input id="_anim_slider9298cc8c32304744b74f8c3090afce01" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9298cc8c32304744b74f8c3090afce01.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim9298cc8c32304744b74f8c3090afce01.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select9298cc8c32304744b74f8c3090afce01" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9298cc8c32304744b74f8c3090afce01"
#              checked>
#       <label for="_anim_radio1_9298cc8c32304744b74f8c3090afce01">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9298cc8c32304744b74f8c3090afce01"
#              >
#       <label for="_anim_radio2_9298cc8c32304744b74f8c3090afce01">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9298cc8c32304744b74f8c3090afce01"
#              >
#       <label for="_anim_radio3_9298cc8c32304744b74f8c3090afce01">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9298cc8c32304744b74f8c3090afce01";
#     var slider_id = "_anim_slider9298cc8c32304744b74f8c3090afce01";
#     var loop_select_id = "_anim_loop_select9298cc8c32304744b74f8c3090afce01";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAUxElEQVR4nO3de5RdZXnH8e+ESUISQIKBMyCXQQUU\
# 8AKMCIJcBQtyE9CK9S4KVlEUaGu9LK21KkURL0UrWJcLo8aiIroUbwiKWoggFQGrlSAUz0gIJNyS\
# gJz+8exxTg5zMjPhzN7P7Pl+1jormb3fYT28c/I77/vud/bua7VaLSRJ6cyqugBJ0tgMaElKyoCW\
# pKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQM\
# aElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElK\
# yoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCWpKQMaElKyoCW\
# pKQMaElKqr/qAjbEokWLGBwcr
